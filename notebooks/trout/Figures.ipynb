# %%
import sys
sys.path.append('../..')
from IPython.display import Image

# %%
import functools
import os
# %matplotlib inline
import plot
import trout
pref = 'trt'
# Out:
# /home/tra/.local/lib/python3.4/site-packages/matplotlib/__init__.py:1157: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /home/tra/.local/lib/python3.4/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
nsnps = [100, 200, 400]

# %% [markdown]
# # Figure 1

# %% [markdown]
# Violin plot of point estimators. With and without logquad correction. Red dot: 10 and 90% of CONFIDENCE intervals

# %% [markdown]
# ## Nb = 50

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_lt_comp(case, 50, "Newb", "None")

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_lt_comp(case, 50, "Newb", "NbNe")

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_lt_comp(case, 50, "Newb", "LogQuad")

# %% [markdown]
# ## Nb = 100

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_lt_comp(case, 100, "Newb", "None")

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_lt_comp(case, 100, "Newb", "NbNe")

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_lt_comp(case, 100, "Newb", "LogQuad")

# %% [markdown]
# # Figure 2

# %% [markdown]
# Different sample sizes

# %% [markdown]
# ## NB = 25

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 90, nsnps, 'allsnps-', 'None')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 90, nsnps, 'allsnps-', 'NbNe')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 90, nsnps, 'allsnps-', 'LogQuad')

# %% [markdown]
# ## Nb = 50

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 180, nsnps, 'allsnps-', 'None')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 180, nsnps, 'allsnps-', 'NbNe')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 180, nsnps, 'allsnps-', 'LogQuad')

# %% [markdown]
# # Nb = 100

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 361, nsnps, 'allsnps-', 'None')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 361, nsnps, 'allsnps-', 'NbNe')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 361, nsnps, 'allsnps-', 'LogQuad')

# %% [markdown]
# # Nb = 200

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 722, nsnps, 'allsnps-', 'None')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 722, nsnps, 'allsnps-', 'NbNe')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_nb(case, 'Newb', 722, nsnps, 'allsnps-', 'LogQuad')

# %% [markdown]
# # Figure 3

# %% [markdown]
# ## Nb = 50

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_cohort(case, "bulltrout", 180, 50, 'None')
# Out:
# All bulltrout 180
# Newb
#  bulltrout 180
# c2c
#  bulltrout 180
# c3c
#  bulltrout 180

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_cohort(case, "bulltrout", 180, 50, 'NbNe')
# Out:
# All bulltrout 180
# Newb
#  bulltrout 180
# c2c
#  bulltrout 180
# c3c
#  bulltrout 180

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_cohort(case, "bulltrout", 180, 50, 'LogQuad')

# %% [markdown]
# ## Nb = 100

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_cohort(case, "bulltrout", 361, 50, 'None')
# Out:
# All bulltrout 361
# Newb
#  bulltrout 361
# c2c
#  bulltrout 361
# c3c
#  bulltrout 361

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_cohort(case, "bulltrout", 361, 50, 'NbNe')
# Out:
# All bulltrout 361
# Newb
#  bulltrout 361
# c2c
#  bulltrout 361
# c3c
#  bulltrout 361

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_cohort(case, "bulltrout", 361, 50, 'LogQuad')
# Out:
# All bulltrout 361
# Newb
#  bulltrout 361
# c2c
#  bulltrout 361
# c3c
#  bulltrout 361

# %% [markdown]
# # Figure 4

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_rel(case, "bulltrout", 361, 50, 'None')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-4a86b782923a> in <module>()
#       1 case = trout.load_file(pref, 40, mydir='../..')
# ----> 2 plot.do_rel(case, "bulltrout", 361, 50, 'None')
#
# /data/atroparvus/tra/AgeStructureNe/plot.py in do_rel(case, model, N0, nindiv, corr_name)
#     180     # box_vals.append(vals)
#     181     # labels.append("MSAT-15")
# --> 182     vals, ci, r2, sr2, j, ssize = case[cohort][(model, N0)][(None, nindiv, 100, "SNP-rel")]
#     183     for cname, corrections in get_corrs(bname, nindiv, vals, ci, r2, sr2, j):
#     184         if cname != corr_name:
#
# KeyError: (None, 50, 100, 'SNP-rel')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_rel(case, "bulltrout", 361, 50, 'NbNe')

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.do_rel(case, "bulltrout", 361, 50, 'LogQuad')

# %% [markdown]
# # Figure 5

# %%
case = trout.load_file(pref, 40, mydir='../..')
plot.compare_correction_ci(case, 'bulltrout', 180, [100], [25, 50, 100], "100snps")

# %% [markdown]
# # Figure 6

# %%
case = trout.load_file(pref, 40, mydir='../..')
linear = [("bullt2", 305), ("bullt2", 610), ("bullt2", 915), ("bullt2", 1220),
          ("bullt2", 1525), ("bullt2", 1830), ("bullt2", 2440),
          ("bullt2", 3050), ("bullt2", 4575), ("bullt2", 6100)]
plot.do_nb_linear(case, linear, "NbNe", functools.partial(trout.correct_ci))
# Out:
# bullt2 305 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 610 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 915 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 1220 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 1525 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 1830 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 2440 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 3050 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 4575 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])
# bullt2 6100 dict_keys([(None, 50, 100, 'SNP'), (None, 25, 200, 'SNP'), (None, 50, 200, 'SNP'), (None, 25, 100, 'SNP')])

# %% [markdown]
# # Figure S1

# %%
plot.do_hz_comp(pref, '../..', "bulltrout", 180)

# %%
plot.do_hz_comp(pref, '../..', "bulltrout", 361)

# %% [markdown]
# # Pcrit

# %%
case = trout.load_file(pref, 25, mydir='../..')
plot.do_pcrit(case, "bulltrout", 361, True)

# %% [markdown]
# # Tables

# %%
case = trout.load_file(pref, 40, mydir='../..')
cis = [("WFrog", "wfrog", 148), ("WFrog", "wfrog", 297),
       ("WFrog", "wfrog", 597),
       ("Mosq", "mosquito", 102), ("Mosq", "mosquito", 167),
       ("Mosq", "mosquito", 210), ("Mosq", "mosquito", 428),
       ("SynSweed", "synseaweed", 81), ("SynSweed", "synseaweed", 164),
       ("SynSweed", "synseaweed", 207),
       ("BuTrout", "bulltrout", 86), ("BuTrout", "bulltrout", 174),
       ("BuTrout", "bulltrout", 353), ("BuTrout", "bulltrout", 713),
       ("WCT-S", "shepard", 513), ("WCT-S", "shepard", 1030),
       ("WCT-F", "fraley", 637), ("WCT-F", "fraley", 1278),
       ("BuLong", "bullt2", 606), ("BuLong", "bullt2", 1214),
       ("BuLong", "bullt2", 1822),
       ("BuLong", "bullt2", 2433), ("BuLong", "bullt2", 3040),
       ("BuLong", "bullt2", 4565), ("BuLong", "bullt2", 6090),
       ("BuPred", "bullpred", 189), ("BuPred", "bullpred", 381),
       ("BuPred", "bullpred", 765)]
medians = plot.do_table_ci(trout.Nbs, case, '../../output/', cis, 100, 50)
##plot.do_table_ci(case, '../../output/', cis, 100, 50, 20)
#plot.do_table_ci(case, '../../output/', cis, 100, 25)
#plot.do_table_ci(case, '../../output/', cis, 200, 50)

# %%
print(medians)
# Out:
# {('bullt2', 606): (10, 13.595906342068538), ('bullt2', 1822): (30, 35.081407970227943), ('fraley', 637): (50, 55.360507648511721), ('bulltrout', 86): (25, 28.049350376642604), ('bullpred', 765): (200, 213.36017820439682), ('wfrog', 297): (50, 51.114849753791219), ('wfrog', 148): (25, 25.016883203877146), ('bullt2', 6090): (100, 108.68246269889647), ('shepard', 1030): (100, 107.51497005837473), ('synseaweed', 164): (40, 42.061464370233317), ('synseaweed', 81): (20, 21.751165864695647), ('bullt2', 1214): (20, 25.603969607691116), ('mosquito', 102): (25, 21.568002432868962), ('bullt2', 4565): (75, 83.417571426409509), ('bullpred', 189): (50, 54.488478095230185), ('fraley', 1278): (100, 110.03713811780767), ('bulltrout', 174): (50, 52.360766892523714), ('bulltrout', 353): (100, 107.45500062535902), ('wfrog', 597): (100, 104.26709273904274), ('bullpred', 381): (100, 108.29001340512535), ('bulltrout', 713): (200, 217.33514712963938), ('bullt2', 3040): (50, 56.594419337992107), ('shepard', 513): (50, 52.846850275772056), ('synseaweed', 207): (50, 51.480315568902753), ('bullt2', 2433): (40, 46.223365172421779), ('mosquito', 210): (50, 46.82130147642313), ('mosquito', 167): (40, 36.246226310793674), ('mosquito', 428): (100, 98.237353975787045)}

# %%
corr_nbs = {}
for (model, N0), val in trout.Nbs.items():
    nb, real = medians[(model, N0)]
    corr_nbs[(model, N0)] = real

# %%
print(corr_nbs)
# Out:
# {('bullt2', 606): 13.595906342068538, ('bullt2', 1822): 35.081407970227943, ('fraley', 637): 55.360507648511721, ('bulltrout', 86): 28.049350376642604, ('wfrog', 297): 51.114849753791219, ('bulltrout', 353): 107.45500062535902, ('wfrog', 148): 25.016883203877146, ('bullt2', 6090): 108.68246269889647, ('shepard', 1030): 107.51497005837473, ('synseaweed', 164): 42.061464370233317, ('synseaweed', 81): 21.751165864695647, ('bullt2', 1214): 25.603969607691116, ('mosquito', 102): 21.568002432868962, ('bullt2', 4565): 83.417571426409509, ('bullpred', 765): 213.36017820439682, ('fraley', 1278): 110.03713811780767, ('bulltrout', 174): 52.360766892523714, ('bullpred', 381): 108.29001340512535, ('wfrog', 597): 104.26709273904274, ('bullpred', 189): 54.488478095230185, ('bulltrout', 713): 217.33514712963938, ('bullt2', 3040): 56.594419337992107, ('shepard', 513): 52.846850275772056, ('synseaweed', 207): 51.480315568902753, ('bullt2', 2433): 46.223365172421779, ('mosquito', 210): 46.82130147642313, ('mosquito', 167): 36.246226310793674, ('mosquito', 428): 98.237353975787045}

# %%
case = trout.load_file(pref, 40, mydir='../..')
corr_medians = plot.do_table_ci(corr_nbs, case, '/tmp/', cis, 100, 50)
# Out:
# WFrog wfrog 148 25.0168832039 0.173882572203
# WFrog
#  wfrog 297 51.1148497538 0.164045287947
# WFrog
#  wfrog 597 104.267092739 0.167358651149
# Mosq
#  mosquito 102 21.5680024329 0.224035470237
# Mosq
#  mosquito 167 36.2462263108 0.205434525706
# Mosq
#  mosquito 210 46.8213014764 0.187493688701
# Mosq
#  mosquito 428 98.2373539758 0.21936665767
# SynSweed
#  synseaweed 81 21.7511658647 0.209130589303
# SynSweed
#  synseaweed 164 42.0614643702 0.196414092898
# SynSweed
#  synseaweed 207 51.4803155689 0.193866635404
# BuTrout
#  bulltrout 86 28.0493503766 0.1693675454
# BuTrout
#  bulltrout 174 52.3607668925 0.149921409977
# BuTrout
#  bulltrout 353 107.455000625 0.174956957709
# BuTrout
#  bulltrout 713 217.33514713 0.255527685527
# WCT-S
#  shepard 513 52.8468502758 0.160842130716
# WCT-S
#  shepard 1030 107.514970058 0.182439431902
# WCT-F
#  fraley 637 55.3605076485 0.159671446794
# WCT-F
#  fraley 1278 110.037138118 0.187092634995
# BuLong
#  bullt2 606 13.5959063421 0.191535127737
# BuLong
#  bullt2 1214 25.6039696077 0.160131419574
# BuLong
#  bullt2 1822 35.0814079702 0.151607142857
# BuLong
#  bullt2 2433 46.2233651724 0.165500715308
# BuLong
#  bullt2 3040 56.594419338 0.160793239094
# BuLong
#  bullt2 4565 83.4175714264 0.187999102652
# BuLong
#  bullt2 6090 108.682462699 0.198582753491
# BuPred
#  bullpred 189 54.4884780952 0.158042988276
# BuPred
#  bullpred 381 108.290013405 0.180903231878
# BuPred
#  bullpred 765 213.360178204 0.244609009211

# %%
case = trout.load_file(pref, 40, mydir='../..')
medians = plot.do_table_ci(trout.Nbs, case, '/tmp/', cis, 100, 50, flex_nb=True)
# Out:
# WFrog wfrog 148 32.071067811865476 25 17.928932188134524
# WFrog
#  wfrog 297 60.0 50 40.0
# WFrog
#  wfrog 597 114.14213562373095 100 85.85786437626905
# Mosq
#  mosquito 102 32.071067811865476 25 17.928932188134524
# Mosq
#  mosquito 167 48.94427190999916 40 31.05572809000084
# Mosq
#  mosquito 210 60.0 50 40.0
# Mosq
#  mosquito 428 114.14213562373095 100 85.85786437626905
# SynSweed
#  synseaweed 81 26.32455532033676 20 13.67544467966324
# SynSweed
#  synseaweed 164 48.94427190999916 40 31.05572809000084
# SynSweed
#  synseaweed 207 60.0 50 40.0
# BuTrout
#  bulltrout 86 32.071067811865476 25 17.928932188134524
# BuTrout
#  bulltrout 174 60.0 50 40.0
# BuTrout
#  bulltrout 353 114.14213562373095 100 85.85786437626905
# BuTrout
#  bulltrout 713 220.0 200 180.0
# WCT-S
#  shepard 513 60.0 50 40.0
# WCT-S
#  shepard 1030 114.14213562373095 100 85.85786437626905
# WCT-F
#  fraley 637 60.0 50 40.0
# WCT-F
#  fraley 1278 114.14213562373095 100 85.85786437626905
# BuLong
#  bullt2 606 14.47213595499958 10 5.52786404500042
# BuLong
#  bullt2 1214 26.32455532033676 20 13.67544467966324
# BuLong
#  bullt2 1822 37.74596669241483 30 22.254033307585168
# BuLong
#  bullt2 2433 48.94427190999916 40 31.05572809000084
# BuLong
#  bullt2 3040 60.0 50 40.0
# BuLong
#  bullt2 4565 87.24744871391589 75 62.75255128608411
# BuLong
#  bullt2 6090 114.14213562373095 100 85.85786437626905
# BuPred
#  bullpred 189 60.0 50 40.0
# BuPred
#  bullpred 381 114.14213562373095 100 85.85786437626905
# BuPred
#  bullpred 765 220.0 200 180.0
